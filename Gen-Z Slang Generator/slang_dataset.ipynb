# %% [markdown]
# <a href="https://colab.research.google.com/github/SeoyeonPark1223/Gemma_FineTuning/blob/main/slang_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
emoji_slang = pd.read_csv("/content/drive/MyDrive/MLB_Kaggle_Gemma/genz_emojis.csv")
word_slang = pd.read_csv("/content/drive/MyDrive/MLB_Kaggle_Gemma/genz_slang.csv")

# %%
emoji_slang.head()
# Out:
#   emoji                      Name  \
# 0     💀                     Skull
# 1     🤡                     Clown
# 2     😭             Loudly crying
# 3     😅  Grinning face with sweat
# 4     👍                 Thumbs up
#
#                                          Description
# 0                       Used as a symbol of laughter
# 1  someone who is acting or saying something incr...
# 2  exclusively used to indicate positive feelings...
# 3                        I’m stressed, but I’m fine.
# 4  Used to send a sarcastic or passive-aggressive...

# %%
emoji = pd.read_csv("/content/drive/MyDrive/MLB_Kaggle_Gemma/genz_emojis.csv")
emoji.rename(columns={'emoji':'Slang'}, inplace=True)
emoji['Description'] = emoji['Name'] +', ' + emoji['Description']
emoji.drop(columns='Name', inplace=True)
emoji_slang = emoji
emoji_slang.head()
# Out:
#   Slang                                        Description
# 0     💀                Skull, Used as a symbol of laughter
# 1     🤡  Clown, someone who is acting or saying somethi...
# 2     😭  Loudly crying, exclusively used to indicate po...
# 3     😅  Grinning face with sweat, I’m stressed, but I’...
# 4     👍  Thumbs up, Used to send a sarcastic or passive...

# %%
word_slang.head()
# Out:
#    keyword                                        description
# 0        W                                  Shorthand for win
# 1        L                          Shorthand for loss/losing
# 2  L+ratio  Response to a comment or action on the interne...
# 3     Dank                  excellent or of very high quality
# 4   Cheugy  Derogatory term for Millennials. Used when mil...

# %%
word_slang.rename(columns={'keyword':'Slang', 'description':'Description'}, inplace=True)
word_slang.head()
# Out:
#      Slang                                        Description
# 0        W                                  Shorthand for win
# 1        L                          Shorthand for loss/losing
# 2  L+ratio  Response to a comment or action on the interne...
# 3     Dank                  excellent or of very high quality
# 4   Cheugy  Derogatory term for Millennials. Used when mil...

# %%
word_slang2 = pd.read_csv("/content/drive/MyDrive/MLB_Kaggle_Gemma/slang.txt", delimiter = '=')
word_slang2.to_csv("slang.csv", index = False)
word_slang2.rename(columns={'AFAIK':'Slang', 'As Far As I Know':'Description'}, inplace=True)
word_slang2.head()
# Out:
#   Slang                  Description
# 0   AFK           Away From Keyboard
# 1  ASAP          As Soon As Possible
# 2   ATK              At The Keyboard
# 3   ATM                At The Moment
# 4    A3  Anytime, Anywhere, Anyplace

# %%
all_slang = pd.concat([emoji_slang, word_slang, word_slang2], ignore_index=True)
all_slang.to_csv("all_slang.csv", index=False)
all_slang
# Out:
#       Slang                                        Description
# 0         💀                Skull, Used as a symbol of laughter
# 1         🤡  Clown, someone who is acting or saying somethi...
# 2         😭  Loudly crying, exclusively used to indicate po...
# 3         😅  Grinning face with sweat, I’m stressed, but I’...
# 4         👍  Thumbs up, Used to send a sarcastic or passive...
# ..      ...                                                ...
# 302  BSAAW                                Big smile and a wink
# 303    BWL                              Bursting with laughter
# 304   LMAO                                 Laughing my ass off
# 305     BFF                               Best friends forever
# 306    CSL                                 Can't stop laughing
#
# [307 rows x 2 columns]

# %%
abbervation_slang = pd.read_csv("/content/drive/MyDrive/MLB_Kaggle_Gemma/abbrevations.csv")
abbervation_slang.rename(columns={'?':'Slang', 'I have a question':'Description'}, inplace=True)
abbervation_slang.head()
# Out:
#   Slang                       Description
# 0     ?  I don’t understand what you mean
# 1   ?4U         I have a question for you
# 2    ;S          GeHmm? What did you say?
# 3    ^^                      read message
# 4    <3                    sideways heart

# %%
all_slang = pd.concat([all_slang, abbervation_slang], ignore_index=True)
all_slang
# Out:
#      Slang                                        Description
# 0        💀                Skull, Used as a symbol of laughter
# 1        🤡  Clown, someone who is acting or saying somethi...
# 2        😭  Loudly crying, exclusively used to indicate po...
# 3        😅  Grinning face with sweat, I’m stressed, but I’...
# 4        👍  Thumbs up, Used to send a sarcastic or passive...
# ...    ...                                                ...
# 4946    ZH                                      Sleeping Hour
# 4947  ZOMG                                          Oh My God
# 4948   ZOT                                     Zero tolerance
# 4949   ZUP                                         What’s up?
# 4950  ZZZZ                                           Sleeping
#
# [4951 rows x 2 columns]

# %%
all_slang.to_csv("all_slang.csv", index=False)
